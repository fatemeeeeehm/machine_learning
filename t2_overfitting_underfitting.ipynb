# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold, learning_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,roc_auc_score
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
lr_model = LinearRegression(normalize=True)
number = 42

# %%
x = np.random.rand(200, 1)
x.shape
y = x + x ** 2 + x ** 3 + x ** 4
y = y + np.random.normal(scale=1, size=y.shape)
y.shape
# Out:
# (200, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_test.shape)
print(x_train.shape)
# Out:
# (40, 1)
# (160, 1)

# %% [markdown]
# # The degree of the polynomial=1

# %%
lr_model.fit(x_train ,y_train)
y_predict = lr_model.predict(x_test)

plt.plot(x_test,y_test, 'co')
plt.plot(x_train, y_train, 'bo')

x_line = np.arange(-0.25, 1.25, 0.1).reshape(-1,1)
y_line = lr_model.predict(x_line)
plt.plot(x_line,y_line, 'r--')

print('Score of train set = {}\nScore of test set = {}' .format(lr_model.score(x_train,y_train),lr_model.score(x_test,y_test)))
# Out:
# Score of train set = 0.4707053146309378
# Score of test set = 0.37179248252470043

# %% [markdown]
# # The degree of the polynomial=2

# %%
from sklearn.preprocessing import PolynomialFeatures  
poly_features = PolynomialFeatures(degree = 2)  
x_poly_train = poly_features.fit_transform(x_train)

lr_model.fit(x_poly_train, y_train)

x_poly_test = poly_features.fit_transform(x_test)
y_poly_predict= lr_model.predict(x_poly_test)

plt.plot(x_test,y_test, 'co')
plt.plot(x_train, y_train, 'bo')

x_line = np.arange(-0.25, 1.25, 0.1).reshape(-1,1)
y_line = lr_model.predict(poly_features.fit_transform(x_line))
plt.plot(x_line,y_line, 'r--')

print('Score of train set = {}\nScore of test set = {}' .format(lr_model.score(x_poly_train,y_train),lr_model.score(x_poly_test,y_test)))
# Out:
# Score of train set = 0.5443396811857717
# Score of test set = 0.35673976209884384

# %% [markdown]
# # The degree of the polynomial=4

# %%
from sklearn.preprocessing import PolynomialFeatures  
poly_features = PolynomialFeatures(degree = 4)  
x_poly_train = poly_features.fit_transform(x_train)

lr_model.fit(x_poly_train, y_train)

x_poly_test = poly_features.fit_transform(x_test)
y_poly_predict= lr_model.predict(x_poly_test)

plt.plot(x_test,y_test, 'co')
plt.plot(x_train, y_train, 'bo')

x_line = np.arange(-0.25, 1.25, 0.1).reshape(-1,1)
y_line = lr_model.predict(poly_features.fit_transform(x_line))
plt.plot(x_line,y_line, 'r--')

print('Score of train set = {}\nScore of test set = {}' .format(lr_model.score(x_poly_train,y_train),lr_model.score(x_poly_test,y_test)))
# Out:
# Score of train set = 0.557022684777845
# Score of test set = 0.33840055749123543

# %% [markdown]
# # The degree of the polynomial= 8

# %%
from sklearn.preprocessing import PolynomialFeatures  
poly_features = PolynomialFeatures(degree = 8)  
x_poly_train = poly_features.fit_transform(x_train)

lr_model.fit(x_poly_train, y_train)

x_poly_test = poly_features.fit_transform(x_test)
y_poly_predict= lr_model.predict(x_poly_test)

plt.plot(x_test,y_test, 'co')
plt.plot(x_train, y_train, 'bo')

x_line = np.arange(-0.25, 1.25, 0.1).reshape(-1,1)
y_line = lr_model.predict(poly_features.fit_transform(x_line))
plt.plot(x_line,y_line, 'r--')

print('Score of train set = {}\nScore of test set = {}' .format(lr_model.score(x_poly_train,y_train),lr_model.score(x_poly_test,y_test)))
# Out:
# Score of train set = 0.5631556563614373
# Score of test set = 0.37755189840065706

# %% [markdown]
# # The degree of the polynomial= 16

# %%
from sklearn.preprocessing import PolynomialFeatures  
poly_features = PolynomialFeatures(degree = 16)  
x_poly_train = poly_features.fit_transform(x_train)

lr_model.fit(x_poly_train, y_train)

x_poly_test = poly_features.fit_transform(x_test)
y_poly_predict= lr_model.predict(x_poly_test)

plt.plot(x_test,y_test, 'co')
plt.plot(x_train, y_train, 'bo')

x_line = np.arange(-0.25, 1.25, 0.1).reshape(-1,1)
y_line = lr_model.predict(poly_features.fit_transform(x_line))
plt.plot(x_line,y_line, 'r--')

print('Score of train set = {}\nScore of test set = {}' .format(lr_model.score(x_poly_train,y_train),lr_model.score(x_poly_test,y_test)))
# Out:
# Score of train set = 0.5682435553649419
# Score of test set = 0.37227859100686034
